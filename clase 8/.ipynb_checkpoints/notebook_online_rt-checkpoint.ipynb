# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12,8)
pd.set_option('max_columns', 120)
pd.set_option('max_colwidth', 5000)

# %% [markdown]
# #### Levantar los datos con pd.read_csv

# %%
pd.read_csv('Online_Retail.csv', encoding="mac_roman")
# Out:
#       InvoiceNo StockCode                          Description  Quantity  \
# 0        536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1        536365     71053                  WHITE METAL LANTERN       6.0
# 2        536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3        536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4        536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
# 5        536365     22752         SET 7 BABUSHKA NESTING BOXES       2.0
# 6        536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER       6.0
# 7        536366     22633               HAND WARMER UNION JACK       6.0
# 8        536366     22632            HAND WARMER RED POLKA DOT       6.0
# 9        536367     84879        ASSORTED COLOUR BIRD ORNAMENT      32.0
# 10       536367     22745           POPPY'S PLAYHOUSE BEDROOM        6.0
# 11       536367     22748            POPPY'S PLAYHOUSE KITCHEN       6.0
# ...

# %% [markdown]
# #### ¿Cuántas filas tienen NaN en *CustomerID*? ¿Cuántas filas tienen NaN en *Description*? Descartar todas las muestras con NaN en alguna columna

# %% [markdown]
# #### ¿Cuántas filas tienen *Quantity* negativa? Descartar todas las muestras con valores negativos en *Quantity*

# %% [markdown]
# #### Que compradores no especificaron su nacionalidad? Descartar estas filas

# %%
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Finland',
#        'Austria', 'Greece', 'Singapore', 'Lebanon',
#        'United Arab Emirates', 'Israel', 'Saudi Arabia', 'Czech Republic',
#        'Canada', 'Brazil', 'USA', 'European Community', 'Bahrain',
#        'Malta', 'RSA'], dtype=object)

# %% [markdown]
# #### Cambiar el tipo de la columna *CustomerID* a int

# %% [markdown]
# #### Tomar las filas en que el *UnitPrice* es 0 y asignarles en *UnitPrice* el valor de la mediana de esta misma columna

# %% [markdown]
# #### Agregar la columna *Revenue* que es el producto de las columnas *Quantity* y *UnitPrice*

# %% [markdown]
# #### Encontrar usando el *CustomerID* los 3 clientes que dieron el mayor *Revenue*. ¿De qué nacionalidad son?

# %%
# Out:
#       InvoiceNo StockCode                        Description  Quantity  \
# 14059    537448     21756           BATH BUILDING BLOCK WORD         6
# 16425    537657     82484  WOOD BLACK BOARD ANT WHITE FINISH       408
# 37952    539491     21981       PACK OF 12 WOODLAND TISSUES         12
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Revenue
# 14059    12/7/10 9:23       6.60       17450  United Kingdom    39.60
# 16425   12/7/10 16:42       4.78       18102  United Kingdom  1950.24
# 37952  12/20/10 10:09       0.29       14646     Netherlands     3.48

# %% [markdown]
# #### Encontrar usando el *CustomerID* los 3 clientes que compraron el mayor número de items (usar la columna *Quantity*) ¿De qué nacionalidad son?

# %%
# Out:
# CustomerID
# 14646    197491
# 16446     80997
# 14911     80515
# Name: Quantity, dtype: int64

# %% [markdown]
# #### Sacando a 'United Kingdom' de *Country*, generar una serie que contenga la revenue total por país. Luego graficar en un gráfico de torta la revenue de los 10 países de mayor revenue

# %% [markdown]
# #### Guardar en otro dataframe solo las filas cuyo país es uno de los 10 países de mayor revenue sin contar 'United Kingdom' (igual que en la consigna anterior). Usando seaborn, realizar un boxplot que tenga en x estos 10 países y en "y" Revenue. Si la mayor parte de los valores en el eje y quedan muy abajo setear el eje "y" en escala logarítmica. ¿Cómo se lee el boxplot?

# %% [markdown]
# #### Encontrar al cliente que mas revenue generó por nacionalidad

# %% [markdown]
# #### Encontrar la compra mas grande por nacionalidad

# %%
# Out:
#                       Quantity  UnitPrice    Revenue
# Country   CustomerID
# Australia 12386            354      23.91     401.90
#           12388           1462     277.77    2780.66
#           12393            816     145.90    1582.60
#           12415          77670    2100.98  125491.73
#           12422            195      51.12     386.20

# %% [markdown]
# #### Graficarlo como grafico de barras

# %% [markdown]
# #### Usando drop_duplicates tirar todos los duplicados de la columna *StockCode* y obtener un dataframe que tiene cada item una vez. Graficar un histograma de los *UnitPrice*. ¿Cuántos items cuestan más de $27?

# %%
# Out:
# (27, 9)
