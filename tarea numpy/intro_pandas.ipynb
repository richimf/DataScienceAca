# %% [markdown]
# # Explorando pandas

# %%
import numpy as np #importo numpy
import pandas as pd #importo pandas
import matplotlib.pyplot as plt #importo matplotlib

# %%
data_mensual = pd.read_csv('elect_mens.csv', delimiter=',')
print(type(data_mensual))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data_mensual.head
# Out:
# <bound method NDFrame.head of     indice_tiempo  demanda_total  demanda_residencial  comercio_e_industria  \
# 0      2001-01-01    6866.260000                  NaN                   NaN
# 1      2001-02-01    6473.100000                  NaN                   NaN
# 2      2001-03-01    6952.300000                  NaN                   NaN
# 3      2001-04-01    6183.350000                  NaN                   NaN
# 4      2001-05-01    6668.940000                  NaN                   NaN
# 5      2001-06-01    6559.160000                  NaN                   NaN
# 6      2001-07-01    6806.800000                  NaN                   NaN
# 7      2001-08-01    6531.180000                  NaN                   NaN
# 8      2001-09-01    6211.660000                  NaN                   NaN
# 9      2001-10-01    6268.030000                  NaN                   NaN
# 10     2001-11-01    6132.660000                  NaN                   NaN
# 11     2001-12-01    6448.414000                  NaN                   NaN
# 12     2002-01-01    6471.690000                  NaN                   NaN
# 13     2002-02-01    5745.320000                  NaN                   NaN
# 14     2002-03-01    6462.130000                  NaN                   NaN
# 15     2002-04-01    5970.250000                  NaN                   NaN
# 16     2002-05-01    6320.570000                  NaN                   NaN
# 17     2002-06-01    6634.900000                  NaN                   NaN
# 18     2002-07-01    6891.220000                  NaN                   NaN
# 19     2002-08-01    6514.580000                  NaN                   NaN
# 20     2002-09-01    6136.420000                  NaN                   NaN
# 21     2002-10-01    6344.780000                  NaN                   NaN
# 22     2002-11-01    6384.030000                  NaN                   NaN
# 23     2002-12-01    6597.000000                  NaN                   NaN
# 24     2003-01-01    7009.410000                  NaN                   NaN
# 25     2003-02-01    6364.910000                  NaN                   NaN
# 26     2003-03-01    6874.260000                  NaN                   NaN
# 27     2003-04-01    6280.380000                  NaN                   NaN
# 28     2003-05-01    6773.800000                  NaN                   NaN
# 29     2003-06-01    6814.530000                  NaN                   NaN
# ..            ...            ...                  ...                   ...
# 186    2016-07-01   11929.645375          5614.534651           4366.110724
# 187    2016-08-01   10855.441952          4663.796035           4249.645917
# 188    2016-09-01   10382.081134          4351.181774           4063.899360
# 189    2016-10-01    9956.038875          3953.447552           3985.591323
# 190    2016-11-01   10132.540584          3970.327674           4142.212910
# 191    2016-12-01   11853.854388          5148.817670           4687.036718
# 192    2017-01-01   12524.865646          5681.816626           4849.049020
# 193    2017-02-01   11074.906499          4618.226100           4551.680399
# 194    2017-03-01   11122.231555          4470.715122           4514.516433
# 195    2017-04-01    9793.758585          3754.330119           3986.428466
# 196    2017-05-01   10795.213415          4524.024791           4137.188624
# 197    2017-06-01   11359.330662          5180.585335           4149.745327
# 198    2017-07-01   11796.425757          5460.615925           4259.809832
# 199    2017-08-01   11107.250705          4767.354968           4209.895737
# 200    2017-09-01   10348.584548          4217.808567           4048.775981
# 201    2017-10-01   10227.329313          3979.758234           4117.571079
# 202    2017-11-01   10355.727486          4035.416488           4174.310998
# 203    2017-12-01   12024.595461          5216.357135           4704.238326
# 204    2018-01-01   12350.183320          5468.423591           4781.012976
# 214                    144.552047         709.335607          68.979392
# 215                    176.728679         787.193081          76.838162
#
#      epesf_distribuidor  recursos_y_energia_formosa_sa     secheep  \
# 0                   NaN                            NaN         NaN
# 1                   NaN                            NaN         NaN
# 2                   NaN                            NaN         NaN
# 3                   NaN                            NaN         NaN
# 4                   NaN                            NaN         NaN
# 5                   NaN                            NaN         NaN
# 6                   NaN                            NaN         NaN
# 7                   NaN                            NaN         NaN
# 8                   NaN                            NaN         NaN
# 9                   NaN                            NaN         NaN
# 10                  NaN                            NaN         NaN
# 11                  NaN                            NaN         NaN
# 12                  NaN                            NaN         NaN
# 13                  NaN                            NaN         NaN
# 14                  NaN                            NaN         NaN
# 15                  NaN                            NaN         NaN
# 16                  NaN                            NaN         NaN
# 17                  NaN                            NaN         NaN
# 18                  NaN                            NaN         NaN
# 19                  NaN                            NaN         NaN
# 20                  NaN                            NaN         NaN
# 21                  NaN                            NaN         NaN
# 22                  NaN                            NaN         NaN
# 23                  NaN                            NaN         NaN
# 24                  NaN                            NaN         NaN
# 25                  NaN                            NaN         NaN
# 26                  NaN                            NaN         NaN
# 27                  NaN                            NaN         NaN
# 28                  NaN                            NaN         NaN
# 29                  NaN                            NaN         NaN
# ..                  ...                            ...         ...
# 186          895.672864                      84.709507  191.444745
# 187          790.456412                      87.712474  182.874138
# 188          728.396706                      83.485283  183.555595
# 189          693.590116                      94.669755  194.564401
# 190          741.342911                      98.397764  226.398924
# 191          920.901103                     125.813534  288.797864
# 192          992.874037                     150.692819  323.798669
# 193          862.419622                     135.323593  267.243387
# 194          850.611907                     123.666222  269.612716
# 195          714.153395                      86.779323  188.811907
# 196          786.937725                      84.065290  188.505153
# 197          829.803995                      83.917267  193.881626
# 198          848.833605                      85.747852  193.002300
# 199          792.156524                      89.981999  191.946561
# 200          721.688457                      92.872377  191.163434
# 201          707.476307                     102.918787  208.823898
# 202          744.194260                     110.065800  233.825807
# 203          924.414929                     156.429256  336.025870
# 204          983.091729                     147.860686  308.466414
# 205          926.583411                     132.424052  292.384087
# 206          850.339845                     127.408401  278.588969
# 207          791.846086                     123.477060  274.028366
# 208          763.311710                      95.706073  215.753386
# 209          862.280999                      83.727531  208.217093
# 210          914.243657                      86.722846  216.541295
# 211          843.827256                      85.945928  205.741252
# 212          673.200618                      91.758059  209.267496
# 213          692.028162                     105.889261  229.381529
# 214          723.963812                     124.201871  257.161872
# 215          836.281823                     148.524384  300.665909
#
#      spse_santa_cruz
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# 5                NaN
# 6                NaN
# 7                NaN
# 8                NaN
# 9                NaN
# 10               NaN
# 11               NaN
# 12               NaN
# 13               NaN
# 14               NaN
# 15               NaN
# 16               NaN
# 17               NaN
# 18               NaN
# 19               NaN
# 20               NaN
# 21               NaN
# 22               NaN
# 23               NaN
# 24               NaN
# 25               NaN
# 26               NaN
# 27               NaN
# 28               NaN
# 29               NaN
# ..               ...
# 186        54.081619
# 187        51.722604
# 188        49.070320
# 189        48.288672
# 190        44.990032
# 191        44.486766
# 192        43.789701
# 193        40.865439
# 194        47.908513
# 195        48.838305
# 196        54.183658
# 197        55.709013
# 198        57.574266
# 199        55.879831
# 200        51.794712
# 201        50.419616
# 202        46.161202
# 203        45.356307
# 204        43.154795
# 205        40.376930
# 206        48.495185
# 207        48.831390
# 208        53.972707
# 209        60.872834
# 210        64.250292
# 211        60.921392
# 212        56.835237
# 213        56.102211
# 214        51.044519
# 215        49.466149
#
# [216 rows x 30 columns]>

# %% [markdown]
# #### ".index" devuelve los nombres de los indices

# %%
data_mensual.index
# Out:
# RangeIndex(start=0, stop=216, step=1)

# %%
data_mensual.columns
# Out:
# Index(['indice_tiempo', 'demanda_total', 'demanda_residencial',
#        'comercio_e_industria', 'grandes_usuarios', 'temperatura_promedio',
#        'potencia_maxima', 'ede_tucuman', 'edelap_sa', 'edenor_distribuidor',
#        'edesal_distribuidor', 'edestesa_emp_dist__este', 'edesur_distribuidor',
#        'emp_de_energia_de_rio_negro_sa', 'emp_dist_energ_atlantica',
#        'emp_de_energia_de_la_rioja_sa', 'emp_dist_energia_de_salta',
#        'emp_electric_misiones_sa', 'empresa_dis_estero_sa',
#        'empresa_jujenia_de_energia_sa', 'energia_de_catamarca_sa',
#        'energia_de_entre_rios_sa', 'energia_de_mendoza_sa',
#        'energia_san_juan_sa_exedessa', 'epec_distribuidor',
#        'epen_distribuidor', 'epesf_distribuidor',
#        'recursos_y_energia_formosa_sa', 'secheep', 'spse_santa_cruz'],
#       dtype='object')

# %% [markdown]
# #### Hay varias operaciones que pueden realizarse utilizando numpy, pero tambien pueden llamarse como funciones integradas a los DataFrames:

# %%
print(np.shape(data_mensual))
print(data_mensual.shape)
# Out:
# (216, 30)
# (216, 30)

# %% [markdown]
# #### El atributo columns nos da el nombre de todas las columanas del DataFrame

# %%
data_mensual.columns
# Out:
# Index(['indice_tiempo', 'demanda_total', 'demanda_residencial',
#        'comercio_e_industria', 'grandes_usuarios', 'temperatura_promedio',
#        'potencia_maxima', 'ede_tucuman', 'edelap_sa', 'edenor_distribuidor',
#        'edesal_distribuidor', 'edestesa_emp_dist__este', 'edesur_distribuidor',
#        'emp_de_energia_de_rio_negro_sa', 'emp_dist_energ_atlantica',
#        'emp_de_energia_de_la_rioja_sa', 'emp_dist_energia_de_salta',
#        'emp_electric_misiones_sa', 'empresa_dis_estero_sa',
#        'empresa_jujenia_de_energia_sa', 'energia_de_catamarca_sa',
#        'energia_de_entre_rios_sa', 'energia_de_mendoza_sa',
#        'energia_san_juan_sa_exedessa', 'epec_distribuidor',
#        'epen_distribuidor', 'epesf_distribuidor',
#        'recursos_y_energia_formosa_sa', 'secheep', 'spse_santa_cruz'],
#       dtype='object')

# %% [markdown]
# #### Podemos acceder a las columnas por su nombre
# #### Las que son *strings* pueden recortarse con el atributo str

# %%
data_mensual['indice_tiempo'].str[5:7]
# Out:
# 0      01
# 1      02
# 2      03
# 3      04
# 4      05
# 5      06
# 6      07
# 7      08
# 8      09
# 9      10
# 10     11
# 11     12
# 12     01
# 13     02
# 14     03
# 15     04
# 16     05
# 17     06
# 18     07
# 19     08
# 20     09
# 21     10
# 22     11
# 23     12
# 24     01
# 25     02
# 26     03
# 27     04
# 28     05
# 29     06
#        ..
# 186    07
# 187    08
# 188    09
# 189    10
# 190    11
# 191    12
# 192    01
# 193    02
# 194    03
# 195    04
# 196    05
# 197    06
# 198    07
# 199    08
# 200    09
# 201    10
# 202    11
# 203    12
# 204    01
# 205    02
# 206    03
# 207    04
# 208    05
# 209    06
# 210    07
# 211    08
# 212    09
# 213    10
# 214    11
# 215    12
# Name: indice_tiempo, Length: 216, dtype: object

# %%
year = data_mensual['indice_tiempo'].str[:4]
month = data_mensual['indice_tiempo'].str[5:7]

# %%
print(month)
# Out:
# 0      01
# 1      02
# 2      03
# 3      04
# 4      05
# 5      06
# 6      07
# 7      08
# 8      09
# 9      10
# 10     11
# 11     12
# 12     01
# 13     02
# 14     03
# 15     04
# 16     05
# 17     06
# 18     07
# 19     08
# 20     09
# 21     10
# 22     11
# 23     12
# 24     01
# 25     02
# 26     03
# 27     04
# 28     05
# 29     06
#        ..
# 186    07
# 187    08
# 188    09
# 189    10
# 190    11
# 191    12
# 192    01
# 193    02
# 194    03
# 195    04
# 196    05
# 197    06
# 198    07
# 199    08
# 200    09
# 201    10
# 202    11
# 203    12
# 204    01
# 205    02
# 206    03
# 207    04
# 208    05
# 209    06
# 210    07
# 211    08
# 212    09
# 213    10
# 214    11
# 215    12
# Name: indice_tiempo, Length: 216, dtype: object

# %%
print(year)
# Out:
# 0      2001
# 1      2001
# 2      2001
# 3      2001
# 4      2001
# 5      2001
# 6      2001
# 7      2001
# 8      2001
# 9      2001
# 10     2001
# 11     2001
# 12     2002
# 13     2002
# 14     2002
# 15     2002
# 16     2002
# 17     2002
# 18     2002
# 19     2002
# 20     2002
# 21     2002
# 22     2002
# 23     2002
# 24     2003
# 25     2003
# 26     2003
# 27     2003
# 28     2003
# 29     2003
#        ...
# 186    2016
# 187    2016
# 188    2016
# 189    2016
# 190    2016
# 191    2016
# 192    2017
# 193    2017
# 194    2017
# 195    2017
# 196    2017
# 197    2017
# 198    2017
# 199    2017
# 200    2017
# 201    2017
# 202    2017
# 203    2017
# 204    2018
# 205    2018
# 206    2018
# 207    2018
# 208    2018
# 209    2018
# 210    2018
# 211    2018
# 212    2018
# 213    2018
# 214    2018
# 215    2018
# Name: indice_tiempo, Length: 216, dtype: object

# %% [markdown]
# #### Podemos renombrar indices modificando el atributo *index*

# %%
data_mensual['mes'] = month

# %%
data_mensual['año']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'año'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-be7a2875941d> in <module>
# ----> 1 data_mensual['año']
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'año'

# %%
data_mensual.index = year

# %%
data_mensual.index
# Out:
# RangeIndex(start=0, stop=216, step=1)

# %%
data_mensual['mes']
# Out:
# 0      01
# 1      02
# 2      03
# 3      04
# 4      05
# 5      06
# 6      07
# 7      08
# 8      09
# 9      10
# 10     11
# 11     12
# 12     01
# 13     02
# 14     03
# 15     04
# 16     05
# 17     06
# 18     07
# 19     08
# 20     09
# 21     10
# 22     11
# 23     12
# 24     01
# 25     02
# 26     03
# 27     04
# 28     05
# 29     06
#        ..
# 186    07
# 187    08
# 188    09
# 189    10
# 190    11
# 191    12
# 192    01
# 193    02
# 194    03
# 195    04
# 196    05
# 197    06
# 198    07
# 199    08
# 200    09
# 201    10
# 202    11
# 203    12
# 204    01
# 205    02
# 206    03
# 207    04
# 208    05
# 209    06
# 210    07
# 211    08
# 212    09
# 213    10
# 214    11
# 215    12
# Name: mes, Length: 216, dtype: object

# %%
data_mensual.drop('indice_tiempo', axis=1)
# Out:
#      demanda_total  demanda_residencial  comercio_e_industria  \
# 0      6866.260000                  NaN                   NaN
# 1      6473.100000                  NaN                   NaN
# 187          790.456412                      87.712474  182.874138
# 188          728.396706                      83.485283  183.555595
# 189          693.590116                      94.669755  194.564401
# 190          741.342911                      98.397764  226.398924
# 191          920.901103                     125.813534  288.797864
# 192          992.874037                     150.692819  323.798669
# 193          862.419622                     135.323593  267.243387
# 194          850.611907                     123.666222  269.612716
# 195          714.153395                      86.779323  188.811907
# 196          786.937725                      84.065290  188.505153
# 197          829.803995                      83.917267  193.881626
# 198          848.833605                      85.747852  193.002300
# 199          792.156524                      89.981999  191.946561
# 200          721.688457                      92.872377  191.163434
# 201          707.476307                     102.918787  208.823898
# 202          744.194260                     110.065800  233.825807
# 203          924.414929                     156.429256  336.025870
# 204          983.091729                     147.860686  308.466414
# 205          926.583411                     132.424052  292.384087
# 206          850.339845                     127.408401  278.588969
# 207          791.846086                     123.477060  274.028366
# 208          763.311710                      95.706073  215.753386
# 209          862.280999                      83.727531  208.217093
# 210          914.243657                      86.722846  216.541295
# 211          843.827256                      85.945928  205.741252
# 212          673.200618                      91.758059  209.267496
# 213          692.028162                     105.889261  229.381529
# 214          723.963812                     124.201871  257.161872
# 215          836.281823                     148.524384  300.665909
#
#      spse_santa_cruz  mes
# 0                NaN   01
# 1                NaN   02
# 2                NaN   03
# 3                NaN   04
# 4                NaN   05
# 5                NaN   06
# 6                NaN   07
# 7                NaN   08
# 8                NaN   09
# 9                NaN   10
# 10               NaN   11
# 11               NaN   12
# 12               NaN   01
# 13               NaN   02
# 14               NaN   03
# 15               NaN   04
# 16               NaN   05
# 17               NaN   06
# 18               NaN   07
# 19               NaN   08
# 20               NaN   09
# 21               NaN   10
# 22               NaN   11
# 23               NaN   12
# 24               NaN   01
# 25               NaN   02
# 26               NaN   03
# 27               NaN   04
# 28               NaN   05
# 29               NaN   06
# ..               ...  ...
# 186        54.081619   07
# 187        51.722604   08
# 188        49.070320   09
# 189        48.288672   10
# 190        44.990032   11
# 191        44.486766   12
# 192        43.789701   01
# 193        40.865439   02
# 194        47.908513   03
# 195        48.838305   04
# 196        54.183658   05
# 197        55.709013   06
# 198        57.574266   07
# 199        55.879831   08
# 200        51.794712   09
# 201        50.419616   10
# 202        46.161202   11
# 203        45.356307   12
# 204        43.154795   01
# 205        40.376930   02
# 206        48.495185   03
# 207        48.831390   04
# 208        53.972707   05
# 209        60.872834   06
# 210        64.250292   07
# 211        60.921392   08
# 212        56.835237   09
# 213        56.102211   10
# 214        51.044519   11
# 215        49.466149   12
#
# [216 rows x 30 columns]

# %%
data_mensual.loc['2001', 'demanda_total']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: '2001'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-aafdda929423> in <module>
# ----> 1 data_mensual.loc['2001', 'demanda_total']
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1492             except (KeyError, IndexError, AttributeError):
#    1493                 pass
# -> 1494             return self._getitem_tuple(key)
#    1495         else:
#    1496             # we by definition only have the 0th axis
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     866     def _getitem_tuple(self, tup):
#     867         try:
# --> 868             return self._getitem_lowerdim(tup)
#     869         except IndexingError:
#     870             pass
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     986         for i, key in enumerate(tup):
#     987             if is_label_like(key) or isinstance(key, tuple):
# --> 988                 section = self._getitem_axis(key, axis=i)
#     989
#     990                 # we have yielded a scalar ?
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1911         # fall thru to straight lookup
#    1912         self._validate_key(key, axis)
# -> 1913         return self._get_label(key, axis=axis)
#    1914
#    1915
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#     139             raise IndexingError('no slices here, handle elsewhere')
#     140
# --> 141         return self.obj._xs(label, axis=axis)
#     142
#     143     def _get_loc(self, key, axis=None):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3583                                                       drop_level=drop_level)
#    3584         else:
# -> 3585             loc = self.index.get_loc(key)
#    3586
#    3587             if isinstance(loc, np.ndarray):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: '2001'

# %%
data_mensual.iloc[0]
# Out:
# indice_tiempo                     2001-01-01
# demanda_total                        6866.26
# demanda_residencial                      NaN
# comercio_e_industria                     NaN
# grandes_usuarios                         NaN
# temperatura_promedio                  25.432
# potencia_maxima                        13501
# ede_tucuman                              NaN
# edelap_sa                                NaN
# edenor_distribuidor                      NaN
# edesal_distribuidor                      NaN
# edestesa_emp_dist__este                  NaN
# edesur_distribuidor                      NaN
# emp_de_energia_de_rio_negro_sa           NaN
# emp_dist_energ_atlantica                 NaN
# emp_de_energia_de_la_rioja_sa            NaN
# emp_dist_energia_de_salta                NaN
# emp_electric_misiones_sa                 NaN
# empresa_dis_estero_sa                    NaN
# empresa_jujenia_de_energia_sa            NaN
# energia_de_catamarca_sa                  NaN
# energia_de_entre_rios_sa                 NaN
# energia_de_mendoza_sa                    NaN
# energia_san_juan_sa_exedessa             NaN
# epec_distribuidor                        NaN
# epen_distribuidor                        NaN
# epesf_distribuidor                       NaN
# recursos_y_energia_formosa_sa            NaN
# secheep                                  NaN
# spse_santa_cruz                          NaN
# mes                                       01
# Name: 0, dtype: object

# %%
data_mensual.drop('indice_tiempo', axis=1, inplace=True)
data_mensual.loc['2001']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: '2001'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-fe7da499e8ef> in <module>
#       1 data_mensual.drop('indice_tiempo', axis=1, inplace=True)
# ----> 2 data_mensual.loc['2001']
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1911         # fall thru to straight lookup
#    1912         self._validate_key(key, axis)
# -> 1913         return self._get_label(key, axis=axis)
#    1914
#    1915
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#     139             raise IndexingError('no slices here, handle elsewhere')
#     140
# --> 141         return self.obj._xs(label, axis=axis)
#     142
#     143     def _get_loc(self, key, axis=None):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3583                                                       drop_level=drop_level)
#    3584         else:
# -> 3585             loc = self.index.get_loc(key)
#    3586
#    3587             if isinstance(loc, np.ndarray):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: '2001'

# %%
temp_2001 = data_mensual.loc['2001', 'temperatura_promedio']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: '2001'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-149fa2f585f1> in <module>
# ----> 1 temp_2001 = data_mensual.loc['2001', 'temperatura_promedio']
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1492             except (KeyError, IndexError, AttributeError):
#    1493                 pass
# -> 1494             return self._getitem_tuple(key)
#    1495         else:
#    1496             # we by definition only have the 0th axis
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     866     def _getitem_tuple(self, tup):
#     867         try:
# --> 868             return self._getitem_lowerdim(tup)
#     869         except IndexingError:
#     870             pass
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     986         for i, key in enumerate(tup):
#     987             if is_label_like(key) or isinstance(key, tuple):
# --> 988                 section = self._getitem_axis(key, axis=i)
#     989
#     990                 # we have yielded a scalar ?
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1911         # fall thru to straight lookup
#    1912         self._validate_key(key, axis)
# -> 1913         return self._get_label(key, axis=axis)
#    1914
#    1915
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#     139             raise IndexingError('no slices here, handle elsewhere')
#     140
# --> 141         return self.obj._xs(label, axis=axis)
#     142
#     143     def _get_loc(self, key, axis=None):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3583                                                       drop_level=drop_level)
#    3584         else:
# -> 3585             loc = self.index.get_loc(key)
#    3586
#    3587             if isinstance(loc, np.ndarray):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: '2001'

# %%
print(type(temp_2001))
print(temp_2001)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-bee958fe3ede> in <module>
# ----> 1 print(type(temp_2001))
#       2 print(temp_2001)
#
# NameError: name 'temp_2001' is not defined

# %%
temp_prom_2001 = np.mean(temp_2001)
print(temp_prom_2001)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-6f852d7acdb9> in <module>
# ----> 1 temp_prom_2001 = np.mean(temp_2001)
#       2 print(temp_prom_2001)
#
# NameError: name 'temp_2001' is not defined

# %%
print(data_mensual.loc['2001', 'temperatura_promedio'].mean())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: '2001'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-a7abdf9d97e9> in <module>
# ----> 1 print(data_mensual.loc['2001', 'temperatura_promedio'].mean())
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1492             except (KeyError, IndexError, AttributeError):
#    1493                 pass
# -> 1494             return self._getitem_tuple(key)
#    1495         else:
#    1496             # we by definition only have the 0th axis
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     866     def _getitem_tuple(self, tup):
#     867         try:
# --> 868             return self._getitem_lowerdim(tup)
#     869         except IndexingError:
#     870             pass
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     986         for i, key in enumerate(tup):
#     987             if is_label_like(key) or isinstance(key, tuple):
# --> 988                 section = self._getitem_axis(key, axis=i)
#     989
#     990                 # we have yielded a scalar ?
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1911         # fall thru to straight lookup
#    1912         self._validate_key(key, axis)
# -> 1913         return self._get_label(key, axis=axis)
#    1914
#    1915
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#     139             raise IndexingError('no slices here, handle elsewhere')
#     140
# --> 141         return self.obj._xs(label, axis=axis)
#     142
#     143     def _get_loc(self, key, axis=None):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3583                                                       drop_level=drop_level)
#    3584         else:
# -> 3585             loc = self.index.get_loc(key)
#    3586
#    3587             if isinstance(loc, np.ndarray):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: '2001'

# %%
data_mensual.loc['2001']['temperatura_promedio']

# %%
print(np.std(temp_2001))
print(data_mensual.loc['2001']['temperatura_promedio'].std(ddof=0))

# %%
print(data_mensual.loc['2001']['temperatura_promedio'])
print(data_mensual.loc['2001','temperatura_promedio'])

# %%
data_mensual.loc[:, 'temperatura_promedio']

# %%
import matplotlib.pyplot as plt
plt.hist(data_mensual.loc[:, 'temperatura_promedio'],bins = 15)
plt.show()

# %%
data_mensual['mes'] == '07'

# %%
data_mensual[data_mensual['mes'] == '07']['temperatura_promedio'].hist(bins=10)

# %%
data_mensual.groupby('mes')['temperatura_promedio']

# %%
data_mensual.groupby('mes')['temperatura_promedio'].mean()

# %%
data_mensual.groupby('mes')['temperatura_promedio'].mean().plot()

# %%
data_mensual.index.get_level_values(0)

# %%
data_mensual.groupby(data_mensual.index.get_level_values(0))['temperatura_promedio'].mean().plot()

# %%
plt.scatter(data_mensual['temperatura_promedio'], data_mensual['demanda_total'], color='k')

# %%
plt.scatter(data_mensual['mes'], data_mensual['demanda_total'], color='k')
data_mensual.groupby('mes')['demanda_total'].mean().plot(color='r')

# %%
data_mensual.groupby('mes').mean()
#data_mensual.groupby('mes')['demanda_total'].mean()

# %%
plt.scatter(data_mensual['mes'], data_mensual['demanda_total'], color='k')
data_mensual.groupby('mes')['demanda_total'].mean().plot(color='r')

# %%
data_mensual.groupby(data_mensual.index.get_level_values(0)).describe()

# %%
data_mensual.iloc[-10:, :]
